# %%
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
import numpy as np

#Normal random noise plus linear relation correlation
randArrX = np.random.rand(5000)
randArrY = np.random.rand(5000)   + randArrX * -0.13

plt.scatter(randArrX,randArrY)
print(spearmanr(randArrX,randArrY))
plt.show()

#With missing and fully randomy points for the first 1000 random points

randArrY[1000:] = np.random.rand(4000)   + randArrX[1000:] * -0.13
randArrY[:1000] = np.median(randArrY[1000:])

plt.scatter(randArrX,randArrY)
print(spearmanr(randArrX,randArrY))
# Out:
# SpearmanrResult(correlation=-0.13106726597869062, pvalue=1.3310555174411711e-20)
# SpearmanrResult(correlation=-0.12332808851899242, pvalue=2.0986406480464124e-18)
